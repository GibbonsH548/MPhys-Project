# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_pickle("C:/Users/gibbo/OneDrive - Lancaster University/Uni stuff/Year 4/MPhys Project/Project Code/testdata20_i.pkl")
df_sorted = df.sort_values(by = "energy").reset_index()
df_sorted = df_sorted.drop("index",axis = 1)

# %%
x1 = []
y1 = []
z1 = []
for i in range(0,6230):#,9731):
    for j in range(len(df_sorted["positions"][0])):
        if j%3 ==0:
            
            x1.append(df_sorted["positions"][i][j])
        if (j-1)%3 ==0:
            y1.append(df_sorted["positions"][i][j])
        if (j-2)%3 == 0:
            z1.append(df_sorted["positions"][i][j])    
#plt.scatter(x1, y1, s = 0.01)
x1 = []
y1 = []
z1 = []
for i in range(6350,9565):#(9879,9971):
    for j in range(len(df_sorted["positions"][0])):
        if j%3 ==0:            
            x1.append(df_sorted["positions"][i][j])
        if (j-1)%3 ==0:
            y1.append(df_sorted["positions"][i][j])
        if (j-2)%3 == 0:
            z1.append(df_sorted["positions"][i][j])    
plt.scatter(x1, y1, s = 0.01)
x1 = []
y1 = []
z1 = []
for i in range(6400,6401):#(9879,9971):
    for j in range(len(df_sorted["positions"][0])):
        if j%3 ==0:            
            x1.append(df_sorted["positions"][i][j])
        if (j-1)%3 ==0:
            y1.append(df_sorted["positions"][i][j])
        if (j-2)%3 == 0:
            z1.append(df_sorted["positions"][i][j])    
plt.scatter(x1, y1, s = 30)
# for i in range(9578,9700):
#     for j in range(len(df_sorted["positions"][0])):
#         if j%3 ==0:            
#             x1.append(df_sorted["positions"][i][j])
#         if (j-1)%3 ==0:
#             y1.append(df_sorted["positions"][i][j])
#         if (j-2)%3 == 0:
#             z1.append(df_sorted["positions"][i][j])   
#plt.scatter(x1, y1, s = 0.1)
# x1 = []
# y1 = []
# z1 = []
# for i in range(0,1):
#     for j in range(len(df_sorted["positions"][0])):
#         if j%3 ==0:            
#             x1.append(df_sorted["positions"][i][j])
#         if (j-1)%3 ==0:
#             y1.append(df_sorted["positions"][i][j])
#         if (j-2)%3 == 0:
#             z1.append(df_sorted["positions"][i][j])   
# plt.scatter(x1, y1, s = 10)
plt.show()

# %% [markdown]
# 0 - 6230 - Plateu 1

# %%
x1 = []
y1 = []
z1 = []
for i in range(9970,9971):#(9879,9971):
    for j in range(len(df_sorted["positions"][0])):
        if j%3 ==0:            
            x1.append(df_sorted["positions"][i][j])
        if (j-1)%3 ==0:
            y1.append(df_sorted["positions"][i][j])
        if (j-2)%3 == 0:
            z1.append(df_sorted["positions"][i][j])    
plt.scatter(x1, y1, s = 10)
# x1 = []
# y1 = []
# z1 = []
# for i in range(9731,9879):#,9731):
#     for j in range(len(df_sorted["positions"][0])):
#         if j%3 ==0:
            
#             x1.append(df_sorted["positions"][i][j])
#         if (j-1)%3 ==0:
#             y1.append(df_sorted["positions"][i][j])
#         if (j-2)%3 == 0:
#             z1.append(df_sorted["positions"][i][j])    
# #plt.scatter(x1, y1, s = 1)
# x1 = []
# y1 = []
# z1 = []
# for i in range(9972,9973):
#     for j in range(len(df_sorted["positions"][0])):
#         if j%3 ==0:
            
#             x1.append(df_sorted["positions"][i][j])
#         if (j-1)%3 ==0:
#             y1.append(df_sorted["positions"][i][j])
#         if (j-2)%3 == 0:
#             z1.append(df_sorted["positions"][i][j])   
# plt.scatter(x1, y1, s = 10)
# plt.show()

# %%
x1 = []
y1 = []
z1 = []
for i in range(0,6230):#,9731):
    for j in range(len(df_sorted["positions"][0])):
        if j%3 ==0:
            
            x1.append(df_sorted["positions"][i][j])
        if (j-1)%3 ==0:
            y1.append(df_sorted["positions"][i][j])
        if (j-2)%3 == 0:
            z1.append(df_sorted["positions"][i][j])    
plt.scatter(x1, y1, s = 0.01)


# y2 = []

# for i in range(1): #len(position_min)
#     for j in range(49):
#         if j%3 ==0:
#             x2.append(df_sorted["positions"][i][j])
#             print(df_sorted["positions"][i][j])
#         if (j-1)%3 ==0:
#             y2.append(df_sorted["positions"][i][j])
#             print()
    #z.append(position_min[i][2])
# fig = plt.figure(figsize=(12, 12))
# ax = fig.add_subplot(projection='3d')

plt.scatter(x1, y1, s = 0.01)
x1 = []
y1 = []
z1 = []
for i in range(6250,9578):
    for j in range(len(df_sorted["positions"][0])):
        if j%3 ==0:
            
            x1.append(df_sorted["positions"][i][j])
        if (j-1)%3 ==0:
            y1.append(df_sorted["positions"][i][j])
        if (j-2)%3 == 0:
            z1.append(df_sorted["positions"][i][j])        
# x2 = []
# y2 = []

# for i in range(1): #len(position_min)
#     for j in range(49):
#         if j%3 ==0:
#             x2.append(df_sorted["positions"][i][j])
#             print(df_sorted["positions"][i][j])
#         if (j-1)%3 ==0:
#             y2.append(df_sorted["positions"][i][j])
#             print()
    #z.append(position_min[i][2])
# fig = plt.figure(figsize=(12, 12))
# ax = fig.add_subplot(projection='3d')

plt.scatter(x1, y1, s = 0.01)
# plt.show()
#plt.scatter(x1, z1, s = 0.01)
# plt.show()
# plt.scatter(y1,z1, s =0.01)
# plt.show()
x1 = []
y1 = []
z1 = []
#ax1.scatter(x2, y2, s = 1)
# plt.set_xlabel('X Label')
# plt.set_ylabel('Y Label')
#ax.set_zlabel('Z Label')
for i in range(9578,9700):
    for j in range(len(df_sorted["positions"][0])):
        if j%3 ==0:
            
            x1.append(df_sorted["positions"][i][j])
        if (j-1)%3 ==0:
            y1.append(df_sorted["positions"][i][j])
        if (j-2)%3 == 0:
            z1.append(df_sorted["positions"][i][j]) 
plt.scatter(x1, y1, s = 0.1)
x1 = []
y1 = []
z1 = []
for i in range(9700,9731):
    for j in range(len(df_sorted["positions"][0])):
        if j%3 ==0:
            
            x1.append(df_sorted["positions"][i][j])
        if (j-1)%3 ==0:
            y1.append(df_sorted["positions"][i][j])
        if (j-2)%3 == 0:
            z1.append(df_sorted["positions"][i][j])   
#plt.scatter(x1, y1, s = 0.1)
x1 = []
y1 = []
z1 = []
for i in range(9731,9760):
    for j in range(len(df_sorted["positions"][0])):
        if j%3 ==0:
            
            x1.append(df_sorted["positions"][i][j])
        if (j-1)%3 ==0:
            y1.append(df_sorted["positions"][i][j])
        if (j-2)%3 == 0:
            z1.append(df_sorted["positions"][i][j])   
plt.scatter(x1, y1, s = 0.1)
#plt.show()
#plt.scatter(x1, z1, s = 0.01)
plt.show()
# plt.scatter(y1,z1, s =0.01)
# plt.show()  
# for i in range(5)
#     initial = df_sorted["positions"][1][j]
fig = plt.figure()
ax1 = fig.add_subplot(1, 1, 1)
ax1.scatter(x1, y1, s = 1)
h =ax1.hist2d(x1, y1, bins=200)
plt.colorbar(h[3])
plt.show()

# fig = plt.figure()
# ax1 = fig.add_subplot(1, 1, 1)
# ax1.scatter(x2, y2, s = 1)
# h =ax1.hist2d(x2, y2, bins=200)
# plt.colorbar(h[3])
# # ax1.set_xlim([-100,100])
# # ax1.set_ylim([-100,100])
# plt.show()

# %%
kg = 2.72328406922e25
#m = 1 #(m = /2.72328406922e-25 kg)
# mu_b = 1
# mu_0 = 


# Variables:
e_i = np.array([0,0,1])
# w_p = 4000    # pancake
# w_z = 2504000
# Convert to sensible units e.g m = 1
w_p_i = 40
w_z_i = 2504000
w_2 = w_p_i**2 + w_z_i**2

t = (w_2**(-1/2))

# %%
z = np.array([1,2,3])
y = np.array([[4,5,6],[7,8,9]])

print(print(type(y)))
# Out:
# <class 'numpy.ndarray'>
# None

# %%
# Joules = 	kg ⋅ m 2 ⋅ s −2
index = []
energies = []
for i in range(0,9900):
    index.append(i)
    energies.append(df_sorted["energy"][i])#*kg**(-1)*(t**2))
    #print(df_sorted["energy"][i])

plt.scatter(index,energies, s = 0.1)

# %%
print(np.gradient(np.array([  -7.61990257, 85.67335852, 37.2231391,  -7.74574812, 83.96260732, 36.8375687])))
print(EDF.V_dx_array(np.array([  -7.61990257, 85.67335852, 37.2231391,  -7.74574812, 83.96260732, 36.8375687])))
# Out:
# [ 93.29326109  22.42152083 -46.70955332  23.36973411  22.29165841
#  -47.12503862]
# [-121918441.12826982, 1370773736.2075794, 233389677727225.56, -123931969.91173017, 1343401717.2324207, 230972145150099.22]

# %%
print(df_sorted.iloc[-1].positions)

print(EDF.V_total(df_sorted.iloc[-1].positions))
print(EDF.V_total(np.array([3.10689970e+00, -3.03721189e+01, -5.44008632e-04, -3.16397546e+01,
  5.61780394e+01, -1.71846121e-09,  9.12691325e+01,  4.45466010e+01,
  2.25947181e-08, -4.33597895e+00, -3.30260298e+01,  5.43973564e-04,
 -6.58178550e+01,  3.14006860e+01, -3.03286241e-09])))
# Out:
# [-3.10689970e+00 -3.03721189e+01 -5.44008632e-04 -3.16397546e+01
#   5.61780394e+01 -1.71846121e-09  9.12691325e+01  4.45466010e+01
#   2.25947181e-08 -4.33597895e+00 -3.30260298e+01  5.43973564e-04
#  -6.58178550e+01  3.14006860e+01 -3.03286241e-09]
# 174650905867.62262
# 174650905846.97543
